# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("UnicornCompanies.csv",parse_dates=['Date Joined','Year Founded'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          1074 non-null   int64
#  1   Company            1074 non-null   object
#  2   Valuation          1074 non-null   object
#  3   Date Joined        1074 non-null   datetime64[ns]
#  4   Industry           1074 non-null   object
#  5   City               1058 non-null   object
#  6   Country            1074 non-null   object
#  7   Continent          1074 non-null   object
#  8   Year Founded       1074 non-null   datetime64[ns]
#  9   Funding            1062 non-null   object
#  10  FundinginMillions  1062 non-null   object
#  11  Select Investors   1073 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 100.8+ KB

# %%
df.head()
# Out:
#    CompanyID    Company Valuation Date Joined  \
# 0          1  Bytedance      180B  2017-04-07
# 1          2     SpaceX      100B  2012-12-01
# 2          3      SHEIN      100B  2018-07-03
# 3          4     Stripe       95B  2014-01-23
# 4          5     Klarna       46B  2011-12-12
#
#                           Industry           City        Country  \
# 0          Artificial intelligence        Beijing          China
# 1                            Other      Hawthorne  United States
# 2  E-commerce & direct-to-consumer       Shenzhen          China
# 3                          Fintech  San Francisco  United States
# 4                          Fintech      Stockholm         Sweden
#
#        Continent Year Founded Funding FundinginMillions  \
# 0           Asia   2012-01-01      8B             8000M
# 1  North America   2002-01-01      7B             7000M
# 2           Asia   2008-01-01      2B             2000M
# 3  North America   2010-01-01      2B             2000M
# ...

# %%
df.insert(2,"Val_B_M",df['Valuation'].str[-1])

# %%
df.head()
# Out:
#    CompanyID    Company Val_B_M Valuation Date Joined  \
# 0          1  Bytedance       B      180B  2017-04-07
# 1          2     SpaceX       B      100B  2012-12-01
# 2          3      SHEIN       B      100B  2018-07-03
# 3          4     Stripe       B       95B  2014-01-23
# 4          5     Klarna       B       46B  2011-12-12
#
#                           Industry           City        Country  \
# 0          Artificial intelligence        Beijing          China
# 1                            Other      Hawthorne  United States
# 2  E-commerce & direct-to-consumer       Shenzhen          China
# 3                          Fintech  San Francisco  United States
# 4                          Fintech      Stockholm         Sweden
#
#        Continent Year Founded Funding FundinginMillions  \
# 0           Asia   2012-01-01      8B             8000M
# 1  North America   2002-01-01      7B             7000M
# 2           Asia   2008-01-01      2B             2000M
# ...

# %%
df['Valuation'] = df['Valuation'].str.extract('(\d+)').astype(float)

# %%
df['Valuation']
# Out:
# 0       180.0
# 1       100.0
# 2       100.0
# 3        95.0
# 4        46.0
#         ...
# 1069      1.0
# 1070      1.0
# 1071      1.0
# 1072      1.0
# 1073      1.0
# Name: Valuation, Length: 1074, dtype: float64

# %%
#df['Valuation'] = df['Valuation'] * 1000000000
df.head()
# Out:
#    CompanyID    Company Val_B_M  Valuation Date Joined  \
# 0          1  Bytedance       B      180.0  2017-04-07
# 1          2     SpaceX       B      100.0  2012-12-01
# 2          3      SHEIN       B      100.0  2018-07-03
# 3          4     Stripe       B       95.0  2014-01-23
# 4          5     Klarna       B       46.0  2011-12-12
#
#                           Industry           City        Country  \
# 0          Artificial intelligence        Beijing          China
# 1                            Other      Hawthorne  United States
# 2  E-commerce & direct-to-consumer       Shenzhen          China
# 3                          Fintech  San Francisco  United States
# 4                          Fintech      Stockholm         Sweden
#
#        Continent Year Founded Funding FundinginMillions  \
# 0           Asia   2012-01-01      8B             8000M
# 1  North America   2002-01-01      7B             7000M
# 2           Asia   2008-01-01      2B             2000M
# ...

# %%
df.insert(10,"fund_B_M",df['FundinginMillions'].str[-1])

# %%
print(type(df['fund_B_M']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head()
# Out:
#    CompanyID    Company Val_B_M  Valuation Date Joined  \
# 0          1  Bytedance       B      180.0  2017-04-07
# 1          2     SpaceX       B      100.0  2012-12-01
# 2          3      SHEIN       B      100.0  2018-07-03
# 3          4     Stripe       B       95.0  2014-01-23
# 4          5     Klarna       B       46.0  2011-12-12
#
#                           Industry           City        Country  \
# 0          Artificial intelligence        Beijing          China
# 1                            Other      Hawthorne  United States
# 2  E-commerce & direct-to-consumer       Shenzhen          China
# 3                          Fintech  San Francisco  United States
# 4                          Fintech      Stockholm         Sweden
#
#        Continent Year Founded fund_B_M Funding FundinginMillions  \
# 0           Asia   2012-01-01        M      8B             8000M
# 1  North America   2002-01-01        M      7B             7000M
# ...

# %%
df['FundinginMillions'] = df['FundinginMillions'].str.extract('(\d+)')
df.head()
# Out:
#    CompanyID    Company Val_B_M  Valuation Date Joined  \
# 0          1  Bytedance       B      180.0  2017-04-07
# 1          2     SpaceX       B      100.0  2012-12-01
# 2          3      SHEIN       B      100.0  2018-07-03
# 3          4     Stripe       B       95.0  2014-01-23
# 4          5     Klarna       B       46.0  2011-12-12
#
#                           Industry           City        Country  \
# 0          Artificial intelligence        Beijing          China
# 1                            Other      Hawthorne  United States
# 2  E-commerce & direct-to-consumer       Shenzhen          China
# 3                          Fintech  San Francisco  United States
# 4                          Fintech      Stockholm         Sweden
#
#        Continent Year Founded fund_B_M Funding FundinginMillions  \
# 0           Asia   2012-01-01        M      8B              8000
# 1  North America   2002-01-01        M      7B              7000
# ...

# %%
df['FundinginMillions']
# Out:
# 0       8000
# 1       7000
# 2       2000
# 3       2000
# 4       4000
#         ...
# 1069     379
# 1070     990
# 1071      80
# 1072     792
# 1073     620
# Name: FundinginMillions, Length: 1074, dtype: object

# %%
df.head(50)
# Out:
#     CompanyID                 Company Val_B_M  Valuation Date Joined  \
# 0           1               Bytedance       B      180.0  2017-04-07
# 1           2                  SpaceX       B      100.0  2012-12-01
# 2           3                   SHEIN       B      100.0  2018-07-03
# 3           4                  Stripe       B       95.0  2014-01-23
# 4           5                  Klarna       B       46.0  2011-12-12
# 5           6                   Canva       B       40.0  2018-01-08
# 6           7            Checkout.com       B       40.0  2019-05-02
# 7           8               Instacart       B       39.0  2014-12-30
# 8           9               JUUL Labs       B       38.0  2017-12-20
# 9          10              Databricks       B       38.0  2019-02-05
# 10         11                 Revolut       B       33.0  2018-04-26
# 11         12              Epic Games       B       32.0  2018-10-26
# 12         13                     FTX       B       32.0  2021-07-20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          1074 non-null   int64
#  1   Company            1074 non-null   object
#  2   Val_B_M            1074 non-null   object
#  3   Valuation          1074 non-null   float64
#  4   Date Joined        1074 non-null   datetime64[ns]
#  5   Industry           1074 non-null   object
#  6   City               1058 non-null   object
#  7   Country            1074 non-null   object
#  8   Continent          1074 non-null   object
#  9   Year Founded       1074 non-null   datetime64[ns]
#  10  fund_B_M           1062 non-null   object
#  11  Funding            1062 non-null   object
#  12  FundinginMillions  1062 non-null   object
#  13  Select Investors   1073 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(10)
# memory usage: 117.6+ KB

# %%
df.to_csv('Unicorn_Companies_edited.csv')

# %%
df = pd.read_csv('InvestorsFinal.csv')

# %%
df.head(10)
# Out:
#    CompanyID                 SelectInvestors
# 0          1           Sequoia Capital China
# 1          2                   Founders Fund
# 2          3         Tiger Global Management
# 3          4                 Khosla Ventures
# 4          5  Institutional Venture Partners
# 5          6           Sequoia Capital China
# 6          7         Tiger Global Management
# 7          8                 Khosla Ventures
# 8          9         Tiger Global Management
# 9         10             Andreessen Horowitz

# %%
df.describe()
# Out:
#          CompanyID
# count  3052.000000
# mean    537.460026
# std     310.946619
# min       1.000000
# 25%     269.000000
# 50%     537.000000
# 75%     807.250000
# max    1074.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3052 entries, 0 to 3051
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CompanyID        3052 non-null   int64
#  1   SelectInvestors  3051 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 47.8+ KB

# %%
df_obj = df.select_dtypes(['object'])
print (df_obj)
# Out:
#                      SelectInvestors
# 0              Sequoia Capital China
# 1                      Founders Fund
# 2            Tiger Global Management
# 3                    Khosla Ventures
# 4     Institutional Venture Partners
# ...                              ...
# 3047             Redpoint e.ventures
# 3048               Redpoint Ventures
# 3049                   Goldman Sachs
# 3050               McKesson Ventures
# 3051                           Accel
#
# [3052 rows x 1 columns]

# %%
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
print (df)
# Out:
#       CompanyID                 SelectInvestors
# 0             1           Sequoia Capital China
# 1             2                   Founders Fund
# 2             3         Tiger Global Management
# 3             4                 Khosla Ventures
# 4             5  Institutional Venture Partners
# ...         ...                             ...
# 3047        150             Redpoint e.ventures
# 3048        247               Redpoint Ventures
# 3049        511                   Goldman Sachs
# 3050        911               McKesson Ventures
# 3051       1026                           Accel
#
# [3052 rows x 2 columns]

# %%
df.to_csv('InvestorsFinal_edited.csv')
